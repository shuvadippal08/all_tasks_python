# %%
a = 10

# %%
a
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b = 10.0
type(b)
# Out:
# float

# %%
c = 10+2j
print(type(c))
# Out:
# <class 'complex'>

# %%
type(True)
# Out:
# bool

# %%
c = 2j
print(type(c))
# Out:
# <class 'complex'>

# %%
id(c)
# Out:
# 1567581261840

# %%
k = 2j+35
print(type(k))
print(id(k))
# Out:
# <class 'complex'>
# 1567581262576

# %%
print(k)
# Out:
# (35+2j)

# %%
x = 2.0j+5
print(type(x))
print(x)
# Out:
# <class 'complex'>
# (5+2j)

# %%
y = 0+0.2j
print(type(y))
print(y)
# Out:
# <class 'complex'>
# 0.2j

# %%
z = 5+2j
print(type(z))
print(z)
# Out:
# <class 'complex'>
# (5+2j)

# %%
S = 'PYTHON'
print(id(S))
# Out:
# 1567555547664

# %%
print(type(S))
# Out:
# <class 'str'>

# %%
str()
# Out:
# ''

# %%
def shuva():
    '''This function belongs to shuvas identuty'''
    print('age 23')
    print('he is learning python')
shuva()
# Out:
# age 23
# he is learning python

# %%
shuva
# Out:
# <function __main__.shuva()>

# %%
def add(a:int, b:int, c:int,d:int) -> int:
    '''this is a sunstraction method'''
    '''a:int --> Type hinting'''
    return (a-b-c-d)*(a-b-c-d)

add(1,2,3,4)
# Out:
# 64
