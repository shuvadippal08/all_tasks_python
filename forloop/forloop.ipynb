# %%
## question 1
import logging

logging.basicConfig(
    filename="vowelcount.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s - %(name)s",
    filemode="a",
    force=True,
)
s = input("enter a string: ")
def vowelcount(s:str)->int:
    """
    Counts the number of vowel in a given string
    Parameters:
        s (str) : Input String
    Returns:
        int: total number of vowels in the string
    """
    logging.info("Counting the number of vowels")
    v='aeiou'
    cnt=0
    for ch in s.lower():
        if ch in v:
            cnt+=1
    logging.info(f"Vowel count in String {s} is {cnt}")
    return cnt
print(vowelcount(s))
# Out:
# 2

# %%
import logging

logging.basicConfig(
    filename="countfreq.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s - %(name)s",
    filemode="a",
    force=True,
)

s = input("enter a string ")

def countfreq(s:str)->dict:
    """
    This is the function which count the frequency for each character in a string
    Parameters:
        s (str) : Input String
    Output:
        k (dict): dict(str, int)
    """
    k={}
    logging.info("Counting the frequency")
    for ch in s:
        k[ch] = s.count(ch)
    logging.info(f"The frequency for each character in string {s} is {k}")
    return k
print(countfreq(s))
# Out:
# {}

# %%
import logging

logging.basicConfig(
    filename="findsecondlargest.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s - %(name)s",
    filemode="a",
    force=True,
)


l = [1,2,3,5,6,8,9,8,6]

def findsecondlargest(l:list[int])->int:
    """
    This function is for finding the second largest element in an given array or list
    Parameters:
        l (list) --> takes list input
    Output:
        Give output as the integer :
        the second largest element
        list must be integer type
    """
    logging.info("Finding the secondlargest element in an array")
    first = 0
    second = 0
    for num in l:
        if num > first:
            second=first
            first=num
        elif num > second and num != first:
            second= num
    logging.info(f"Second largest number found: {second} in the list {l}")
    return second

findsecondlargest(l)
# Out:
# 8

# %%
import logging

logging.basicConfig(
    filename="sortedAscendingornot.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s - %(name)s",
    filemode="a",
    force=True,
)


l1 = [1,5,6,2,8,9]
logging.info("finding list is in sorted manner or not if sorted ascending or not")
def sortedAscendingornot(l:list[int])->None:
    """
    This is a function to show the what if the array is sorted or not if sorted or not
    Parameters:
        l (list[int]): Input list
    Output:
        none: instead of output it returns the
    """
    if sorted(l):
        if(l[0]<l[len(l)-1]):
            logging.info(f"List {l} is sorted in ascending order")
            print("List is sorted in ascending order")
        elif (l[0]>l[len()]):
            logging.info(f"List {l} is sorted in Descending order")
            print("List is sorted in descending order")
    else:
        logging.info(f"{l} is not sorted")
        print(f"{l} is not sorted")
sortedAscendingornot(l)
# Out:
# List is sorted in ascending order

# %%
import logging

logging.basicConfig(
    filename="findmissingfrom1ton.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s - %(name)s",
    filemode="a",
    force=True,
)

l=[1,2,3,4,5,7]
def findmissingfrom1ton(l:list[int])->int:
    """
    This is a function which finds the missing number from an array 1 to n
    Parameter:
        l :(list[int]) --> Input list
    Output:
        num: int--> the missing number
    """
    n = len(l)+1
    actsum=n*(n+1)//2
    s = sum(l)
    k=abs(actsum-s)

    logging.info(f"The number found: {k}")
    return k
findmissingfrom1ton(l)
# Out:
# 6

# %%
import logging

logging.basicConfig(
    filename="remove_duplicates_preserve_order.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s - %(name)s",
    filemode="a",
    force=True,
)

def remove_duplicates_preserve_order(lst):
    """
    Removes duplicate elements from a list while preserving the original order.

    Args:
        lst (list): Input list that may contain duplicate elements.

    Returns:
        list: A new list with duplicates removed, order preserved.
    """
    logging.info("Starting duplicate removal process")

    seen = set()
    result = []

    for item in lst:
        logging.debug(f"Checking item: {item}")

        if item not in seen:
            seen.add(item)
            result.append(item)
            logging.info(f"Added {item} to result")
        else:
            logging.info(f"Skipped duplicate item: {item}")

    logging.info("Duplicate removal completed")
    return result


l = [1, 1, 2, 3, 5, 6, 6, 4, 9, 7, 8, 3]
output = remove_duplicates_preserve_order(l)
print(output)
# Out:
# [1, 2, 3, 5, 6, 4, 9, 7, 8]
