# %%
s = "Python is very very easy language"
l = [(word, len(word)) for word  in set(s.split())]
print(l)
# Out:
# [('very', 4), ('language', 8), ('is', 2), ('easy', 4), ('Python', 6)]

# %%
ord('a')
# Out:
# 97

# %%
chr(97)
# Out:
# 'a'

# %%
inp = "hai HelLO"
k = {ch: ord(ch) for ch in inp if ch.isupper()}
k
# Out:
# {'H': 72, 'L': 76, 'O': 79}

# %%
import re
# s = "Python is very easy and aweful easy"
re.search("Python","Python is very easy and aweful")
# Out:
# <re.Match object; span=(0, 6), match='Python'>

# %%
import re
m=re.search(r"\d+","age is 21")
m.group()
# Out:
# '21'

# %%
import re
m= re.search(r"(\d+)-(\d+)","2025-02")
m
# Out:
# <re.Match object; span=(0, 7), match='2025-02'>
