# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sugarcane.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.drop(columns="Unnamed: 0", inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America       768.678.382                  3.668,531
# 1     India           Asia       348.448.000                     260721
# 2     China           Asia       123.059.739                      88287
# 3  Thailand           Asia        87.468.496                  1.264,303
# 4  Pakistan           Asia        65.450.704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     103 non-null    object
#  1   Continent                   103 non-null    object
#  2   Production (Tons)           103 non-null    object
#  3   Production per Person (Kg)  103 non-null    object
#  4   Acreage (Hectare)           102 non-null    object
#  5   Yield (Kg / Hectare)        102 non-null    object
# dtypes: object(6)
# memory usage: 5.0+ KB

# %%
# cols = [
#     'Production (Tons)',
#     'Production per Person (Kg)',
#     'Acreage (Hectare)',
#     'Yield (Kg / Hectare)'
# ]

# %%
df[col] = (
    df[col]
    .astype(str)
    .str.replace('[.,]', '', regex=True)
    .astype('int64', errors='ignore')
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     103 non-null    object
#  1   Continent                   103 non-null    object
#  2   Production (Tons)           103 non-null    int64
#  3   Production per Person (Kg)  103 non-null    object
#  4   Acreage (Hectare)           102 non-null    object
#  5   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 5.0+ KB

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America          768678382                  3.668,531
# 1     India           Asia          348448000                     260721
# 2     China           Asia          123059739                      88287
# 3  Thailand           Asia           87468496                  1.264,303
# 4  Pakistan           Asia           65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df.rename(columns={
    'Production (Tons)':'Production_Tons',
    'Production per Person (Kg)':'Production_per_Person_kg',
    'Acreage (Hectare)':'Acreage_hectare',
    'Yield (Kg / Hectare)':'Yeild_kg_Hectare'
},inplace=True)

# %%
df.head()
# Out:
#     Country      Continent  Production_Tons Production_per_Person_kg  \
# 0    Brazil  South America        768678382                3.668,531
# 1     India           Asia        348448000                   260721
# 2     China           Asia        123059739                    88287
# 3  Thailand           Asia         87468496                1.264,303
# 4  Pakistan           Asia         65450704                   324219
#
#   Acreage_hectare Yeild_kg_Hectare
# 0      10.226.205         75.167,5
# 1       4.950.000         70.393,5
# 2       1.675.215         73.459,1
# 3       1.336.575         65.442,2
# 4       1.130.820           57.879

# %%
df.isnull().sum()
# Out:
# Country                     0
# Continent                   0
# Production_Tons             0
# Production_per_Person_kg    0
# Acreage_hectare             1
# Yeild_kg_Hectare            1
# dtype: int64

# %%
df[df.Acreage_hectare.isnull()]
# Out:
#      Country Continent  Production_Tons Production_per_Person_kg  \
# 99  Djibouti    Africa               53                       51
#
#    Acreage_hectare Yeild_kg_Hectare
# 99             NaN              NaN

# %%
df[df.Yeild_kg_Hectare.isnull()]
# Out:
#      Country Continent  Production_Tons Production_per_Person_kg  \
# 99  Djibouti    Africa               53                       51
#
#    Acreage_hectare Yeild_kg_Hectare
# 99             NaN              NaN

# %%
df.drop(index=99,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#     Country      Continent  Production_Tons Production_per_Person_kg  \
# 0    Brazil  South America        768678382                3.668,531
# 1     India           Asia        348448000                   260721
# 2     China           Asia        123059739                    88287
# 3  Thailand           Asia         87468496                1.264,303
# 4  Pakistan           Asia         65450704                   324219
#
#   Acreage_hectare Yeild_kg_Hectare
# 0      10.226.205         75.167,5
# 1       4.950.000         70.393,5
# 2       1.675.215         73.459,1
# 3       1.336.575         65.442,2
# 4       1.130.820           57.879

# %%
df.tail()
# Out:
#        Country Continent  Production_Tons Production_per_Person_kg  \
# 97       Spain    Europe              394                        8
# 98     Lebanon      Asia               97                       16
# 99   Singapore      Asia               50                        9
# 100      Samoa   Oceania               12                        6
# 101      Syria      Asia                1                        0
#
#     Acreage_hectare Yeild_kg_Hectare
# 97                9         43.596,5
# 98                3         28.386,4
# 99                2               25
# 100               1         11.949,8
# 101               0         83.034,2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   102 non-null    object
#  1   Continent                 102 non-null    object
#  2   Production_Tons           102 non-null    int64
#  3   Production_per_Person_kg  102 non-null    object
#  4   Acreage_hectare           102 non-null    object
#  5   Yeild_kg_Hectare          102 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.9+ KB

# %%
df.nunique()
# Out:
# Country                     102
# Continent                     6
# Production_Tons             102
# Production_per_Person_kg    101
# Acreage_hectare             102
# Yeild_kg_Hectare            102
# dtype: int64

# %%
df.Continent.value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
counts = df['Continent'].value_counts()

plt.barh(counts.index, counts.values)
plt.title("Continent and plots")
plt.xlabel("No of Countries")
plt.ylabel("Continent")
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.Continent.unique()
# Out:
# array(['South America', 'Asia', 'North America', 'Oceania', 'Africa',
#        'Europe'], dtype=object)
