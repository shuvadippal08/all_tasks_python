# %%
def safe_div():
    try:
        a = int(input("Enter a number: "))
        b = int(input("Enter the divisor: "))
        c = a/b
        print(f'{a}/{b}={c}')
    except ZeroDivisionError:
        print("Division by zero not allowed")
    except ValueError:
        print("Enter a integer value or float value not string or object")


safe_div()
# Out:
# Division by zero not allowed

# %%
try:
    a = eval(input("Enter the number: "))
    b = eval(input("Enter the value: "))
    c = a/b
    print(c)
except Exception as e:
    print("Exception is handled, ERROR: ",e)
# Out:
# Exception is handled, ERROR:  name 'A' is not defined

# %%
# try:
#     a = 100000000
#     for i in range(0,a):
#         print(i,end=' ')
# except Exception as e:
#     print("Exception is handled: ",e)

# %% [markdown]
# ## **Default Exception**

# %% [markdown]
# ## **Default Exception**

# %%
production = int(input("Enter the production count: "))
if production < 0:
    raise ValueError("Out of Stock")
else:
    print("Product is available")
# Out:
# Product is available

# %% [markdown]
# ## **Self made exception**

# %%
class AgeError(Exception):
    pass
age = int(input("Enter the age:"))
if age < 18:
    raise AgeError("Age must be 18 or above")
else:
    print("Eligible")
# Out:
# ---------------------------------------------------------------------------
# AgeError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       3 age = int(input("Enter the age:"))
#       4 if age < 18:
# ----> 5     raise AgeError("Age must be 18 or above")
#       6 else:
#       7     print("Eligible")
#
# AgeError: Age must be 18 or above

# %% [markdown]
# ## Assertion Error

# %%
s1 = input("Enter the String 1:  ")
s2 = input("Enter the String 2:  ")
assert len(s1) == len(s2), "Length is different"
print("Length is same")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 s1 = input("Enter the String 1:  ")
#       2 s2 = input("Enter the String 2:  ")
# ----> 3 assert len(s1) == len(s2), "Length is different"
#       4 print("Length is same")
#
# AssertionError: Length is different
